# %%
import os
import sys

# 현재 경로에서 상위 디렉토리(프로젝트 루트)로 이동
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

# 기존 경로에서 중복된 항목들을 제거하고 프로젝트 루트를 맨 앞에 추가
sys.path = [project_root] + list(dict.fromkeys(sys.path))

import folium
import math
import numpy as np
from folium.map import Marker
from folium.features import DivIcon
from src.db.maria_client import fetch_orders
from src.model.distance import distance
from ortools.constraint_solver import pywrapcp, routing_enums_pb2
from geopy.distance import geodesic

# %%
df = fetch_orders()
points = [
    {
        "id": int(row["id"]),
        "latitude": row["latitude"],
        "longitude": row["longitude"],
        "address1": row["address1"],
        "address2": row["address2"],
    }
    for _, row in df.iterrows()
]

depots = [
    {"id": "depot_화성", "latitude": 37.157541, "longitude": 126.834845, "address1": "화성 허브센터", "address2": "", "demand": 0},
    {"id": "depot_이천", "latitude": 37.201687, "longitude": 127.459751, "address1": "이천 마장센터", "address2": "", "demand": 0},
    {"id": "depot_수원", "latitude": 37.263573, "longitude": 127.028601, "address1": "수원센터", "address2": "", "demand": 0},
    {"id": "depot_천안", "latitude": 36.815076, "longitude": 127.113818, "address1": "천안센터", "address2": "", "demand": 0},
    {"id": "depot_일산", "latitude": 37.705338, "longitude": 126.769166, "address1": "일산센터", "address2": "", "demand": 0},
    {"id": "depot_하남", "latitude": 37.535095, "longitude": 127.206303, "address1": "하남센터", "address2": "", "demand": 0},
    {"id": "depot_광주", "latitude": 37.413294, "longitude": 127.255902, "address1": "광주센터", "address2": "", "demand": 0},
    {"id": "depot_기흥", "latitude": 37.274234, "longitude": 127.115570, "address1": "기흥센터", "address2": "", "demand": 0}
]

# %%
# 필요한 라이브러리 임포트
import numpy as np  # 수치 계산을 위한 라이브러리
from sklearn.cluster import KMeans  # 군집화를 위한 라이브러리
from geopy.distance import geodesic  # 위경도 기반 거리 계산
import folium  # 지도 시각화
from folium.map import Marker
from folium.features import DivIcon
import math  # 수학 연산
from ortools.constraint_solver import pywrapcp, routing_enums_pb2  # Google OR-Tools (경로 최적화)
from functools import lru_cache  # 캐싱 데코레이터
import concurrent.futures  # 병렬 처리
from datetime import datetime
import os
import sys

# 프로젝트 루트 디렉토리 설정
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path = [project_root] + list(dict.fromkeys(sys.path))

# 데이터베이스 관련 모듈 임포트
from src.db.maria_client import fetch_orders
from src.model.distance import distance

# 거리 계산 함수에 캐싱 적용 (동일한 입력에 대해 재계산 방지)
@lru_cache(maxsize=10000)
def calculate_distance(point1, point2):
    """
    두 지점 간의 거리를 계산하는 함수
    Args:
        point1: (위도, 경도) 튜플
        point2: (위도, 경도) 튜플
    Returns:
        float: 두 지점 간의 거리(km)
    """
    return geodesic(point1, point2).km

def balance_vehicle_loads(points, depot, num_vehicles, max_working_minutes=420):
    """
    시간 밸런싱을 고려하여 차량별로 배송지점을 할당하는 함수
    
    Args:
        points: 배송지점 리스트
        depot: 물류센터 정보
        num_vehicles: 사용 가능한 차량 수
        max_working_minutes: 최대 근무 시간(분)
    
    Returns:
        list: 차량별로 할당된 배송지점 리스트
    """
    # 각 배송지점까지의 예상 소요 시간 계산
    point_times = []
    for point in points:
        # depot부터 배송지점까지의 거리 계산
        dist = calculate_distance(
            (depot['latitude'], depot['longitude']),
            (point['latitude'], point['longitude'])
        )
        # 왕복 시간 + 서비스 시간(5분) 계산
        # 속도는 30km/h로 가정
        time = (dist * 2 * 60 / 30) + 5
        point_times.append((point, time))
    
    # 소요 시간이 긴 순서대로 정렬
    point_times.sort(key=lambda x: x[1], reverse=True)
    
    # 차량별 배송지점 및 시간 초기화
    vehicle_loads = [[] for _ in range(num_vehicles)]  # 차량별 배송지점
    vehicle_times = [0] * num_vehicles  # 차량별 누적 시간
    
    # 가장 긴 시간이 필요한 배송지점부터 차례로 할당
    for point, time in point_times:
        # 현재 누적 시간이 가장 적은 차량 선택
        min_time_vehicle = min(range(num_vehicles), key=lambda i: vehicle_times[i])
        
        # 선택된 차량에 배송지점 할당
        vehicle_loads[min_time_vehicle].append(point)
        vehicle_times[min_time_vehicle] += time
    
    return vehicle_loads

def optimize_vehicle_route(depot, points, vehicle_capacity, max_working_minutes=420, avg_speed_kmh=30):
    """
    단일 차량의 경로를 최적화하는 함수
    
    Args:
        depot: 물류센터 정보
        points: 배송지점 리스트
        vehicle_capacity: 차량 용량
        max_working_minutes: 최대 근무 시간(분)
        avg_speed_kmh: 평균 이동 속도(km/h)
    
    Returns:
        dict: 최적화된 경로 정보
    """
    if not points:
        return None
    
    # depot과 배송지점을 합친 전체 경로 포인트
    all_points = [depot] + points
    size = len(all_points)
    
    # 거리 행렬 계산
    coordinates = [(p['latitude'], p['longitude']) for p in all_points]
    dist_matrix = np.zeros((size, size))
    for i in range(size):
        for j in range(i + 1, size):
            dist = calculate_distance(coordinates[i], coordinates[j])
            dist_matrix[i][j] = dist * 1000  # km -> m 변환
            dist_matrix[j][i] = dist * 1000
    
    # OR-Tools 라우팅 모델 설정
    manager = pywrapcp.RoutingIndexManager(size, 1, 0)  # size, 차량수, 시작점
    routing = pywrapcp.RoutingModel(manager)
    
    # 거리 콜백 함수 정의
    def distance_callback(from_index, to_index):
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return int(dist_matrix[from_node][to_node])
    
    # 거리 콜백 등록
    transit_callback_index = routing.RegisterTransitCallback(distance_callback)
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)
    
    # 시간 제약 설정
    def time_callback(from_index, to_index):
        dist = distance_callback(from_index, to_index)
        travel_time = dist / 1000 * (60 / avg_speed_kmh)  # 이동 시간
        service_time = 5 if manager.IndexToNode(to_index) > 0 else 0  # 서비스 시간
        return int(travel_time + service_time)
    
    # 시간 콜백 등록 및 제약 조건 설정
    time_callback_index = routing.RegisterTransitCallback(time_callback)
    routing.AddDimension(
        time_callback_index,
        10,  # 허용 대기 시간
        max_working_minutes,  # 최대 근무 시간
        True,  # 시작 시간 고정
        'Time'
    )
    
    # 시간 비용 설정
    time_dimension = routing.GetDimensionOrDie('Time')
    time_dimension.SetGlobalSpanCostCoefficient(100)
    
    # 경로 탐색 파라미터 설정
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC
    )
    search_parameters.local_search_metaheuristic = (
        routing_enums_pb2.LocalSearchMetaheuristic.GUIDED_LOCAL_SEARCH
    )
    search_parameters.time_limit.seconds = 2  # 탐색 시간 제한
    
    # 경로 최적화 실행
    solution = routing.SolveWithParameters(search_parameters)
    
    if not solution:
        return None
    
    # 최적화된 경로 추출
    route = []
    route_distance = 0
    route_time = 0
    index = routing.Start(0)
    
    while not routing.IsEnd(index):
        node_index = manager.IndexToNode(index)
        route.append(all_points[node_index])
        
        previous_index = index
        index = solution.Value(routing.NextVar(index))
        
        if not routing.IsEnd(index):
            route_distance += routing.GetArcCostForVehicle(previous_index, index, 0)
            route_time += time_callback(previous_index, index)
    
    return {
        'route': route,
        'distance': route_distance / 1000.0,  # m -> km 변환
        'time': route_time
    }

def create_clusters(points, depot, num_vehicles):
    """
    지역 기반으로 배송지점을 클러스터링하는 함수
    - 방향성과 거리를 고려하여 구역을 분할
    """
    if not points:
        return []
    
    # 각 포인트의 각도와 거리 계산
    point_angles = []
    for point in points:
        # depot 기준 각도 계산
        angle = math.atan2(
            point['latitude'] - depot['latitude'],
            point['longitude'] - depot['longitude']
        )
        # depot부터의 거리 계산
        dist = calculate_distance(
            (depot['latitude'], depot['longitude']),
            (point['latitude'], point['longitude'])
        )
        point_angles.append((point, angle, dist))
    
    # 각도 기준 정렬 (-π ~ π)
    point_angles.sort(key=lambda x: x[1])
    
    # 각도와 거리를 고려한 균등 분할
    clusters = [[] for _ in range(num_vehicles)]
    total_workload = sum(pa[2] for pa in point_angles)  # 총 거리
    target_workload = total_workload / num_vehicles     # 차량당 목표 거리
    
    current_cluster = 0
    current_workload = 0
    
    for point, angle, dist in point_angles:
        clusters[current_cluster].append(point)
        current_workload += dist
        
        # 현재 클러스터의 작업량이 목표치를 초과하면 다음 클러스터로
        if current_workload >= target_workload and current_cluster < num_vehicles - 1:
            current_cluster += 1
            current_workload = 0
    
    return clusters

def optimize_vehicle_route(depot, points, vehicle_capacity, max_working_minutes=420, avg_speed_kmh=30):
    """
    단일 차량의 경로를 최적화하는 함수
    - 경로 겹침 패널티 추가
    - 시간 효율성 개선
    """
    if not points:
        return None
    
    all_points = [depot] + points
    size = len(all_points)
    
    # 거리 행렬 계산
    coordinates = [(p['latitude'], p['longitude']) for p in all_points]
    dist_matrix = np.zeros((size, size))
    
    for i in range(size):
        for j in range(i + 1, size):
            dist = calculate_distance(coordinates[i], coordinates[j])
            dist_matrix[i][j] = dist * 1000
            dist_matrix[j][i] = dist * 1000
    
    manager = pywrapcp.RoutingIndexManager(size, 1, 0)
    routing = pywrapcp.RoutingModel(manager)
    
    def distance_callback(from_index, to_index):
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return int(dist_matrix[from_node][to_node])
    
    transit_callback_index = routing.RegisterTransitCallback(distance_callback)
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)
    
    # 시간 제약 설정 개선
    def time_callback(from_index, to_index):
        dist = distance_callback(from_index, to_index)
        travel_time = dist / 1000 * (60 / avg_speed_kmh)
        
        # 배송지점 타입에 따른 서비스 시간 차등 적용
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        
        # depot이 아닌 경우에만 서비스 시간 추가
        service_time = 5 if to_node > 0 else 0
        
        return int(travel_time + service_time)
    
    time_callback_index = routing.RegisterTransitCallback(time_callback)
    routing.AddDimension(
        time_callback_index,
        10,  # 허용 대기 시간
        max_working_minutes,
        True,
        'Time'
    )
    
    # 시간 제약 가중치 설정
    time_dimension = routing.GetDimensionOrDie('Time')
    time_dimension.SetGlobalSpanCostCoefficient(100)
    
    # 경로 최적화 파라미터 설정
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PARALLEL_CHEAPEST_INSERTION
    )
    search_parameters.local_search_metaheuristic = (
        routing_enums_pb2.LocalSearchMetaheuristic.GUIDED_LOCAL_SEARCH
    )
    search_parameters.time_limit.seconds = 3
    
    solution = routing.SolveWithParameters(search_parameters)
    
    if not solution:
        return None
    
    # 최적화된 경로 추출
    route = []
    route_distance = 0
    route_time = 0
    index = routing.Start(0)
    
    while not routing.IsEnd(index):
        node_index = manager.IndexToNode(index)
        route.append(all_points[node_index])
        
        previous_index = index
        index = solution.Value(routing.NextVar(index))
        
        if not routing.IsEnd(index):
            route_distance += routing.GetArcCostForVehicle(previous_index, index, 0)
            route_time += time_callback(previous_index, index)
    
    return {
        'route': route,
        'distance': route_distance / 1000.0,
        'time': route_time
    }

def optimize_routes_for_depot(depot, points, vehicle_capacity=35):
    """
    특정 물류센터의 모든 배송 경로를 최적화하는 함수
    - 클러스터링 방식 개선
    - 시간 밸런싱 강화
    """
    if not points:
        return [], {}
    
    num_vehicles = math.ceil(len(points) / vehicle_capacity)
    
    # 지역 기반 클러스터링 적용
    clusters = create_clusters(points, depot, num_vehicles)
    
    routes = []
    total_distance = 0
    total_time = 0
    vehicle_times = []
    
    for vehicle_id, cluster in enumerate(clusters):
        if not cluster:
            continue
        
        route_info = optimize_vehicle_route(
            depot, 
            cluster, 
            vehicle_capacity,
            max_working_minutes=420,
            avg_speed_kmh=30
        )
        
        if route_info:
            route_info['vehicle_id'] = vehicle_id
            routes.append(route_info)
            total_distance += route_info['distance']
            total_time += route_info['time']
            vehicle_times.append(route_info['time'])
    
    # 시간 통계 계산
    time_std = np.std(vehicle_times) if vehicle_times else 0
    time_mean = np.mean(vehicle_times) if vehicle_times else 0
    
    stats = {
        'depot_id': depot['id'],
        'total_points': len(points),
        'total_vehicles': len(routes),
        'total_distance': total_distance,
        'total_time': total_time,
        'avg_distance_per_vehicle': total_distance / len(routes) if routes else 0,
        'avg_time_per_vehicle': total_time / len(routes) if routes else 0,
        'time_efficiency': total_time / (len(routes) * 420) if routes else 0,
        'time_std': time_std,
        'time_cv': (time_std / time_mean * 100) if time_mean > 0 else 0
    }
    
    return routes, stats

    """
    특정 물류센터의 모든 배송 경로를 최적화하는 함수
    
    Args:
        depot: 물류센터 정보
        points: 배송지점 리스트
        vehicle_capacity: 차량당 최대 배송지점 수
    
    Returns:
        tuple: (최적화된 경로 리스트, 통계 정보)
    """
    if not points:
        return [], {}
    
    # 필요한 차량 수 계산
    num_vehicles = math.ceil(len(points) / vehicle_capacity)
    
    # 시간 밸런싱을 고려하여 배송지점 분배
    balanced_points = balance_vehicle_loads(points, depot, num_vehicles)
    
    # 결과 저장용 변수 초기화
    routes = []
    total_distance = 0
    total_time = 0
    vehicle_times = []
    
    # 각 차량별 경로 최적화
    for vehicle_id, cluster in enumerate(balanced_points):
        if not cluster:
            continue
        
        # 개별 차량 경로 최적화
        route_info = optimize_vehicle_route(
            depot, 
            cluster, 
            vehicle_capacity,
            max_working_minutes=420,  # 7시간
            avg_speed_kmh=30
        )
        
        if route_info:
            route_info['vehicle_id'] = vehicle_id
            routes.append(route_info)
            total_distance += route_info['distance']
            total_time += route_info['time']
            vehicle_times.append(route_info['time'])
    
    # 시간 관련 통계 계산
    time_std = np.std(vehicle_times) if vehicle_times else 0
    time_mean = np.mean(vehicle_times) if vehicle_times else 0
    
    # 통계 정보 생성
    stats = {
        'depot_id': depot['id'],
        'total_points': len(points),
        'total_vehicles': len(routes),
        'total_distance': total_distance,
        'total_time': total_time,
        'avg_distance_per_vehicle': total_distance / len(routes) if routes else 0,
        'avg_time_per_vehicle': total_time / len(routes) if routes else 0,
        'time_efficiency': total_time / (len(routes) * 420) if routes else 0,
        'time_std': time_std,  # 소요시간 표준편차
        'time_cv': (time_std / time_mean * 100) if time_mean > 0 else 0  # 변동계수
    }
    
    return routes, stats

def visualize_routes(routes, depots):
    """
    최적화된 경로를 지도에 시각화하는 함수
    
    Args:
        routes: 최적화된 경로 리스트
        depots: 물류센터 리스트
    
    Returns:
        folium.Map: 시각화된 지도 객체
    """
    if not routes or not depots:
        return None
    
    # 지도 중심점 계산
    center_lat = np.mean([d['latitude'] for d in depots])
    center_lon = np.mean([d['longitude'] for d in depots])
    
    # 기본 지도 생성
    m = folium.Map(location=[center_lat, center_lon], zoom_start=12)
    
    # 경로별 색상 설정
    colors = ['red', 'blue', 'green', 'purple', 'orange', 'darkred', 
              'lightblue', 'darkblue', 'darkgreen', 'cadetblue']
    
    # 물류센터 마커 추가
    for depot in depots:
        folium.Marker(
            location=[depot['latitude'], depot['longitude']],
            popup=f"Depot: {depot['id']}",
            icon=folium.Icon(color='black', icon='info-sign')
        ).add_to(m)
    
    # 각 경로 시각화
    for route_info in routes:
        color = colors[route_info['vehicle_id'] % len(colors)]
        route = route_info['route']
        
        # 경로 라인 그리기
        locations = [[p['latitude'], p['longitude']] for p in route]
        folium.PolyLine(
            locations=locations,
            color=color,
            weight=2,
            opacity=0.8,
            popup=f"Distance: {route_info['distance']:.1f}km, Time: {route_info['time']:.0f}min"
        ).add_to(m)
        
        # 배송지점 마커 추가
        for i, point in enumerate(route[1:], 1):
            folium.CircleMarker(
                location=[point['latitude'], point['longitude']],
                radius=6,
                color=color,
                fill=True,
                popup=f"Stop {i}: {point.get('id', 'N/A')}"
            ).add_to(m)
    
    return m

def main(points, depots):
    """
    메인 실행 함수 - 상세한 결과 출력
    """
    # 수원 물류센터 선택
    suwon_depot = next(d for d in depots if d['id'] == 'depot_수원')
    
    print("\n=== 초기 데이터 정보 ===")
    print(f"전체 배송지점 수: {len(points):,}개")
    print(f"물류센터 수: {len(depots)}개")
    
    # 수원 지역 배송지점 필터링
    suwon_points = []
    for point in points:
        dist = calculate_distance(
            (point['latitude'], point['longitude']),
            (suwon_depot['latitude'], suwon_depot['longitude'])
        )
        if dist <= 15:  # 15km 반경
            suwon_points.append(point)
    
    print(f"\n=== 수원 센터 기본 정보 ===")
    print(f"센터 위치: ({suwon_depot['latitude']:.6f}, {suwon_depot['longitude']:.6f})")
    print(f"배송권역 반경: 15km")
    print(f"배송지점 수: {len(suwon_points):,}개")
    
    # 경로 최적화 실행
    routes, stats = optimize_routes_for_depot(suwon_depot, suwon_points)
    
    print("\n=== 최적화 결과 상세 분석 ===")
    print("\n1. 전체 운영 통계")
    print(f"- 총 배송지점: {stats['total_points']:,}개")
    print(f"- 투입 차량 수: {stats['total_vehicles']}대")
    print(f"- 총 이동거리: {stats['total_distance']:.1f}km")
    print(f"- 총 소요시간: {stats['total_time']:.0f}분 ({stats['total_time']/60:.1f}시간)")
    print(f"- 시간 효율성: {stats['time_efficiency']:.1%}")
    
    print("\n2. 차량당 평균 통계")
    print(f"- 평균 배송지점: {stats['total_points']/stats['total_vehicles']:.1f}개")
    print(f"- 평균 이동거리: {stats['avg_distance_per_vehicle']:.1f}km")
    print(f"- 평균 소요시간: {stats['avg_time_per_vehicle']:.0f}분 ({stats['avg_time_per_vehicle']/60:.1f}시간)")
    print(f"- 소요시간 표준편차: {stats['time_std']:.1f}분")
    print(f"- 소요시간 변동계수: {stats['time_cv']:.1f}%")
    
    print("\n3. 개별 차량 상세 정보")
    times = []
    distances = []
    stops = []
    
    for i, route in enumerate(routes, 1):
        times.append(route['time'])
        distances.append(route['distance'])
        stops.append(len(route['route'])-1)  # depot 제외
        
        print(f"\n[차량 {i}번]")
        print(f"- 배송지점 수: {len(route['route'])-1}개")
        print(f"- 이동거리: {route['distance']:.1f}km")
        print(f"- 소요시간: {route['time']:.0f}분 ({route['time']/60:.1f}시간)")
        
        # 경로 상세 정보
        print("- 상세 경로:")
        for j, point in enumerate(route['route']):
            if j == 0:
                print(f"  출발: {point['address1']} ({point['latitude']:.6f}, {point['longitude']:.6f})")
            else:
                print(f"  배송{j}: {point.get('address1', 'N/A')} ({point['latitude']:.6f}, {point['longitude']:.6f})")
    
    print("\n4. 시간 분포 분석")
    print(f"- 최소 소요시간: {min(times):.0f}분 ({min(times)/60:.1f}시간)")
    print(f"- 최대 소요시간: {max(times):.0f}분 ({max(times)/60:.1f}시간)")
    print(f"- 시간 범위: {max(times) - min(times):.0f}분")
    print(f"- 평균 소요시간: {np.mean(times):.0f}분 ({np.mean(times)/60:.1f}시간)")
    print(f"- 중앙값 소요시간: {np.median(times):.0f}분")
    
    print("\n5. 거리 분포 분석")
    print(f"- 최소 이동거리: {min(distances):.1f}km")
    print(f"- 최대 이동거리: {max(distances):.1f}km")
    print(f"- 거리 범위: {max(distances) - min(distances):.1f}km")
    print(f"- 평균 이동거리: {np.mean(distances):.1f}km")
    print(f"- 중앙값 이동거리: {np.median(distances):.1f}km")
    
    print("\n6. 배송지점 분포 분석")
    print(f"- 최소 배송지점: {min(stops)}개")
    print(f"- 최대 배송지점: {max(stops)}개")
    print(f"- 배송지점 범위: {max(stops) - min(stops)}개")
    print(f"- 평균 배송지점: {np.mean(stops):.1f}개")
    print(f"- 중앙값 배송지점: {np.median(stops):.0f}개")
    
    print("\n7. 효율성 지표")
    print(f"- km당 배송지점: {stats['total_points']/stats['total_distance']:.2f}개/km")
    print(f"- 시간당 배송지점: {stats['total_points']/(stats['total_time']/60):.2f}개/시간")
    print(f"- 차량당 평균 가동률: {stats['time_efficiency']:.1%}")
    
    # 지도 시각화
    print("\n=== 지도 시각화 생성 중 ===")
    m = visualize_routes(routes, [suwon_depot])
    return m

# 프로그램 실행
m = main(points, depots)
display(m)
# Out:
# === 초기 데이터 정보 ===
# 전체 배송지점 수: 221개
# 물류센터 수: 8개
#
# === 수원 센터 기본 정보 ===
# 센터 위치: (37.263573, 127.028601)
# 배송권역 반경: 15km
# 배송지점 수: 221개
#
# === 최적화 결과 상세 분석 ===
#
# 1. 전체 운영 통계
# - 총 배송지점: 221개
# - 투입 차량 수: 7대
# - 총 이동거리: 124.7km
# - 총 소요시간: 1258분 (21.0시간)
# - 시간 효율성: 42.8%
#
# 2. 차량당 평균 통계
# - 평균 배송지점: 31.6개
# - 평균 이동거리: 17.8km
# - 평균 소요시간: 180분 (3.0시간)
# - 소요시간 표준편차: 45.1분
# - 소요시간 변동계수: 25.1%
#
# 3. 개별 차량 상세 정보
#
# [차량 1번]
# - 배송지점 수: 38개
# - 이동거리: 20.8km
# - 소요시간: 217분 (3.6시간)
# - 상세 경로:
#   출발: 수원센터 (37.263573, 127.028601)
#   배송1: 경기도 수원시 권선구 권선로694번길 25 (권선동, 수원시청역 SK VIEW) (37.257779, 127.027665)
#   배송2: 경기도 수원시 권선구 경수대로302번길 29 (권선동, 권선삼성아파트) (37.253907, 127.022824)
#   배송3: 경기도 수원시 권선구 장다리로 20 (세류동) (37.252372, 127.018413)
#   배송4: 경기도 수원시 권선구 세지로5번길 10-12 (세류동) (37.253514, 127.014469)
#   배송5: 경기도 수원시 권선구 세지로5번길 10-12 (세류동) (37.253514, 127.014469)
#   배송6: 경기도 수원시 권선구 정조로 410(세류동) (37.246710, 127.014985)
#   배송7: 경기도 수원시 권선구 동수원로145번길 24(권선동, 수원아이파크시티2단지) (37.245120, 127.029458)
#   배송8: 경기도 수원시 권선구 곡선로 10 (권선동, 수원아이파크시티5단지) (37.239160, 127.025664)
#   배송9: 경기도 수원시 권선구 동수원로58번길 21 (곡반정동, 한솔아파트) (37.235713, 127.027325)
#   배송10: 경기도 수원시 권선구 동수원로58번길 21 (곡반정동, 한솔아파트) (37.235713, 127.027325)
#   배송11: 경기도 수원시 권선구 동수원로58번길 21 (곡반정동, 한솔아파트) (37.235713, 127.027325)
#   배송12: 경기도 수원시 권선구 동수원로58번길 21 (곡반정동, 한솔아파트) (37.235713, 127.027325)
#   배송13: 경기도 수원시 권선구 동수원로46번길 7-15 (곡반정동) (37.235942, 127.025672)
#   배송14: 경기도 수원시 권선구 서수원로 99 (오목천동, 수원권선 꿈에그린 아파트) (37.235139, 126.975232)
#   배송15: 경기도 수원시 권선구 서부로 1534 (고색동, 대한아파트) (37.246201, 126.979313)
#   배송16: 경기도 수원시 권선구 서부로 1534 (고색동, 대한아파트) (37.246201, 126.979313)
#   배송17: 경기도 수원시 권선구 고색로 8 (고색동, 우림필유) (37.248294, 126.977667)
#   배송18: 경기도 수원시 권선구 온정로9번길 36 (오목천동, 오목천역 서희스타힐스아파트) (37.248173, 126.962796)
#   배송19: 경기도 수원시 권선구 호매실로 103(호매실동, 엘에이치호매실스타힐스) (37.254083, 126.959067)
#   배송20: 경기도 수원시 권선구 호매실로166번길 63(호매실동, 호매실스위첸) (37.259941, 126.960859)
#   배송21: 경기도 수원시 권선구 호매실로218번길 22 (호매실동, 호매실마을 14단지 벨섬시티) (37.262579, 126.960449)
#   배송22: 경기도 수원시 권선구 서부로1670번길 33 (고색동) (37.256666, 126.975843)
#   배송23: 경기도 수원시 권선구 권선로 341 (서둔동) (37.260620, 126.987917)
#   배송24: 경기도 수원시 권선구 권선로357번길 30 (서둔동) (37.261723, 126.990840)
#   배송25: 경기도 수원시 권선구 권선로357번길 30 (서둔동) (37.261723, 126.990840)
#   배송26: 경기도 수원시 권선구 권선로357번길 54 (서둔동) (37.262008, 126.991740)
#   배송27: 경기도 수원시 권선구 권선로357번길 78 (서둔동) (37.261128, 126.992733)
#   배송28: 경기도 수원시 권선구 권선로436번길 21(평동, 평동동남아파트) (37.262411, 127.000755)
#   배송29: 경기도 수원시 권선구 권선로436번길 21(평동, 평동동남아파트) (37.262411, 127.000755)
#   배송30: 경기도 수원시 권선구 권선로488번길 7 (세류동) (37.263329, 127.004994)
#   배송31: 경기도 수원시 권선구 세권로 1 (세류동, 수원역센트럴어반시티) (37.261157, 127.005718)
#   배송32: 경기도 수원시 권선구 세권로34번길 12 (세류동) (37.259133, 127.007866)
#   배송33: 경기도 수원시 권선구 정조로565번길 22-5 (세류동, walkerhill 1st B동) (37.260197, 127.011412)
#   배송34: 경기도 수원시 권선구 세권로107번길 15 (세류동) (37.258414, 127.016440)
#   배송35: 경기도 수원시 권선구 세지로 69(세류동) (37.258193, 127.017272)
#   배송36: 경기도 수원시 권선구 세지로 69(세류동) (37.258193, 127.017272)
#   배송37: 경기도 수원시 권선구 세지로66번길 7-9 (권선동, 권선에스빌) (37.258175, 127.017829)
#   배송38: 경기도 수원시 권선구 경수대로381번길 6-9 (권선동) (37.261075, 127.023534)
#
# [차량 2번]
# - 배송지점 수: 45개
# - 이동거리: 14.0km
# - 소요시간: 237분 (4.0시간)
# - 상세 경로:
#   출발: 수원센터 (37.263573, 127.028601)
#   배송1: 경기도 수원시 권선구 효원로256번길 33(권선동) (37.260414, 127.029290)
#   배송2: 경기도 수원시 팔달구 권선로 731 (인계동) (37.258271, 127.031249)
#   배송3: 경기도 수원시 권선구 동수원로146번길 101 (곡반정동) (37.245807, 127.034101)
#   배송4: 경기도 수원시 권선구 동수원로146번길 52 (곡반정동) (37.244887, 127.032220)
#   배송5: 경기도 수원시 권선구 동수원로146번길 52 (곡반정동) (37.244887, 127.032220)
#   배송6: 경기도 수원시 권선구 동수원로145번길 24(권선동, 수원아이파크시티2단지) (37.245120, 127.029458)
#   배송7: 경기도 수원시 권선구 동수원로145번길 24(권선동, 수원아이파크시티2단지) (37.245120, 127.029458)
#   배송8: 경기도 수원시 권선구 동수원로145번길 24(권선동, 수원아이파크시티2단지) (37.245120, 127.029458)
#   배송9: 경기도 수원시 권선구 곡선로50번길 13-6 (곡반정동) (37.237949, 127.029802)
#   배송10: 경기도 수원시 권선구 곡선로49번길 32-20 (곡반정동, 곡반정동빌딩) (37.239780, 127.031646)
#   배송11: 경기도 수원시 권선구 곡선로49번길 32-20 (곡반정동, 곡반정동빌딩) (37.239780, 127.031646)
#   배송12: 경기도 수원시 권선구 곡반정로 133 (곡반정동) (37.239953, 127.032064)
#   배송13: 경기도 수원시 권선구 망포로 14 (곡반정동, 수원 하늘채 더퍼스트2단지) (37.239229, 127.033758)
#   배송14: 경기도 수원시 권선구 망포로 14 (곡반정동, 수원 하늘채 더퍼스트2단지) (37.239197, 127.033767)
#   배송15: 경기도 수원시 권선구 망포로 14 (곡반정동, 수원 하늘채 더퍼스트2단지) (37.239197, 127.033767)
#   배송16: 경기도 수원시 영통구 태장로7번길 38 (망포동, 망포쌍용에듀파크) (37.239452, 127.047602)
#   배송17: 경기도 수원시 영통구 태장로36번길 8 (망포동, 영통푸르지오트레센츠) (37.237922, 127.049682)
#   배송18: 경기도 수원시 영통구 태장로82번길 32 (망포동, 동수원자이1차) (37.236749, 127.053647)
#   배송19: 경기도 수원시 영통구 태장로82번길 32(망포동, 동수원자이1차) (37.236749, 127.053647)
#   배송20: 경기도 수원시 영통구 태장로82번길 32(망포동, 동수원자이1차) (37.236749, 127.053647)
#   배송21: 경기도 수원시 영통구 태장로82번길 32 (망포동, 동수원자이1차) (37.236749, 127.053647)
#   배송22: 경기도 수원시 영통구 태장로71번길 19 (망포동, 동수원 자이2차 아파트) (37.241033, 127.052020)
#   배송23: 경기도 수원시 영통구 태장로71번길 19 (망포동, 동수원 자이2차 아파트) (37.241033, 127.052020)
#   배송24: 경기도 수원시 영통구 영통로154번길 56 (망포동, 한양수자인 에듀파크) (37.240813, 127.057328)
#   배송25: 경기도 수원시 영통구 영통로154번길 56 (망포동, 한양수자인 에듀파크) (37.240813, 127.057328)
#   배송26: 경기도 수원시 영통구 영통로200번길 112 (망포동, 영통 SK VIEW) (37.243012, 127.062230)
#   배송27: 경기도 수원시 영통구 청명남로4번길 21-4 (영통동) (37.249902, 127.074747)
#   배송28: 경기도 수원시 영통구 봉영로1517번길 76 (영통동, 동보.신명 아파트) (37.250660, 127.065576)
#   배송29: 경기도 수원시 영통구 봉영로1517번길 76 (영통동, 동보.신명 아파트) (37.250660, 127.065576)
#   배송30: 경기도 수원시 영통구 봉영로1517번길 76 (영통동, 동보.신명 아파트) (37.250660, 127.065576)
#   배송31: 경기도 수원시 영통구 봉영로1517번길 76 (영통동, 동보.신명 아파트) (37.250660, 127.065576)
#   배송32: 경기도 수원시 영통구 영통로 232 (영통동, 두산.우성.한신아파트) (37.247681, 127.060324)
#   배송33: 경기도 수원시 영통구 영통로 232 (영통동, 두산.우성.한신아파트) (37.247681, 127.060324)
#   배송34: 경기도 수원시 영통구 영통로200번길 20(망포동, 망포역 아이파크) (37.244315, 127.057181)
#   배송35: 경기도 수원시 영통구 덕영대로1499번길 71-1 (망포동) (37.247480, 127.053609)
#   배송36: 경기도 수원시 영통구 삼성로 11(신동, 래미안 영통마크원 2단지) (37.246479, 127.045963)
#   배송37: 경기도 수원시 영통구 권선로908번길 72 (신동, 래미안 영통마크원 1단지) (37.245873, 127.043284)
#   배송38: 경기도 수원시 권선구 매탄로 11(권선동, 현대아파트) (37.253492, 127.036719)
#   배송39: 경기도 수원시 권선구 동수원로285번길 26-17 (권선동) (37.256329, 127.034746)
#   배송40: 경기도 수원시 권선구 동수원로285번길 26-17 (권선동) (37.256329, 127.034746)
#   배송41: 경기도 수원시 팔달구 권선로 753(인계동) (37.257676, 127.033726)
#   배송42: 경기도 수원시 팔달구 효원로308번길 58-9 (인계동) (37.257859, 127.033677)
#   배송43: 경기도 수원시 팔달구 효원로308번길 58-17 (인계동) (37.258153, 127.033176)
#   배송44: 경기도 수원시 팔달구 효원로308번길 16 (인계동, 한화 꿈에그린 파크) (37.260117, 127.034500)
#   배송45: 경기도 수원시 권선구 효원로256번길 7 (권선동) (37.261642, 127.029767)
#
# [차량 3번]
# - 배송지점 수: 40개
# - 이동거리: 23.3km
# - 소요시간: 227분 (3.8시간)
# - 상세 경로:
#   출발: 수원센터 (37.263573, 127.028601)
#   배송1: 경기도 수원시 팔달구 인계로108번길 27-17 (인계동) (37.266516, 127.030048)
#   배송2: 경기도 수원시 팔달구 인계로138번길 8 (인계동) (37.266700, 127.032415)
#   배송3: 경기도 수원시 팔달구 인계로138번길 8 (인계동) (37.266700, 127.032415)
#   배송4: 경기도 수원시 팔달구 권광로263번길 19 (인계동, 인계파크빌 101) (37.270938, 127.034258)
#   배송5: 경기도 수원시 팔달구 권광로 275-8(인계동) (37.272102, 127.035239)
#   배송6: 경기도 수원시 영통구 권광로260번길 36 (매탄동, 현대힐스테이트아파트) (37.271697, 127.039624)
#   배송7: 경기도 수원시 영통구 중부대로256번길 35(매탄동) (37.273018, 127.043201)
#   배송8: 경기도 수원시 팔달구 중부대로223번길 102 (우만동, 주공아파트) (37.281522, 127.040350)
#   배송9: 경기도 수원시 영통구 광교중앙로49번길 40(원천동, 광교원천 경기행복주택) (37.280391, 127.049924)
#   배송10: 경기도 수원시 영통구 에듀타운로106번길 46 (이의동) (37.290500, 127.047001)
#   배송11: 경기도 수원시 영통구 웰빙타운로 50 (이의동, 광교2차 e편한세상) (37.306733, 127.046491)
#   배송12: 경기도 수원시 영통구 센트럴파크로127번길 5-4 (이의동) (37.294929, 127.055475)
#   배송13: 경기도 수원시 영통구 센트럴파크로128번길 107(이의동) (37.295028, 127.056562)
#   배송14: 경기도 수원시 영통구 센트럴파크로 100 (이의동, 광교 센트럴타운 오드카운티) (37.291928, 127.058556)
#   배송15: 경기도 수원시 영통구 법조로149번길 171 (하동) (37.292832, 127.070298)
#   배송16: 경기도 수원시 영통구 센트럴파크로 34 (하동, 광교센트럴타운62단지) (37.289158, 127.063592)
#   배송17: 경기도 수원시 영통구 광교호수공원로 277(원천동, 광교중흥에스클래스) (37.282407, 127.058239)
#   배송18: 경기도 수원시 영통구 광교호수공원로 155 (원천동, 수원광교에일린의뜰) (37.278166, 127.058966)
#   배송19: 경기도 수원시 영통구 광교호수로152번길 80(하동, 광교호반마을21단지) (37.277523, 127.067992)
#   배송20: 경기도 수원시 영통구 삼성로320번길 62 (영통동, 영통아이파크) (37.266311, 127.071376)
#   배송21: 경기도 수원시 영통구 봉영로1770번길 21 (영통동, 신명.한국아파트) (37.267983, 127.083775)
#   배송22: 경기도 수원시 영통구 봉영로1770번길 21 (영통동, 신명.한국아파트) (37.267983, 127.083775)
#   배송23: 경기도 수원시 영통구 영통로514번길 53 (영통동, 영통 센트럴파크뷰) (37.265552, 127.080133)
#   배송24: 경기도 수원시 영통구 영통로 498(영통동, 황골마을주공1단지아파트) (37.262405, 127.079500)
#   배송25: 경기도 수원시 영통구 청명북로 81(영통동, 청명마을주공아파트) (37.258031, 127.079296)
#   배송26: 경기도 수원시 영통구 반달로35번길 30 (영통동) (37.251781, 127.077461)
#   배송27: 경기도 수원시 영통구 반달로35번길 30 (영통동) (37.251781, 127.077461)
#   배송28: 경기도 수원시 영통구 매영로310번길 12 (영통동, 신성.신안.쌍용.진흥아파트) (37.254389, 127.065834)
#   배송29: 경기도 수원시 영통구 신원로 259-2(매탄동) (37.258720, 127.060310)
#   배송30: 경기도 수원시 영통구 삼성로277번길 29-51 (원천동) (37.266863, 127.062928)
#   배송31: 경기도 수원시 영통구 매영로159번길 23-4 (원천동) (37.266741, 127.060866)
#   배송32: 경기도 수원시 영통구 매영로159번길 23-4 (원천동) (37.266741, 127.060866)
#   배송33: 경기도 수원시 영통구 매영로159번길 23-4 (원천동) (37.266741, 127.060866)
#   배송34: 경기도 수원시 영통구 중부대로448번길 28 (원천동, 원천 레이크파크아파트) (37.268691, 127.060876)
#   배송35: 경기도 수원시 영통구 동탄원천로 1035(매탄동, 매탄3차삼성아파트) (37.266193, 127.050320)
#   배송36: 경기도 수원시 영통구 매탄로196번길 23-13 (매탄동) (37.267685, 127.047302)
#   배송37: 경기도 수원시 영통구 매영로 42-1 (매탄동) (37.269008, 127.047489)
#   배송38: 경기도 수원시 영통구 매영로 10 (매탄동, 삼성2차아파트) (37.269401, 127.043513)
#   배송39: 경기도 수원시 팔달구 효원로307번길 87(인계동, 한화 꿈에그린 효원 102동) (37.264921, 127.036645)
#   배송40: 경기도 수원시 팔달구 효원로249번길 46-8 (인계동) (37.264194, 127.030310)
#
# [차량 4번]
# - 배송지점 수: 29개
# - 이동거리: 16.1km
# - 소요시간: 163분 (2.7시간)
# - 상세 경로:
#   출발: 수원센터 (37.263573, 127.028601)
#   배송1: 경기도 수원시 팔달구 경수대로 652 (우만동) (37.283701, 127.028943)
#   배송2: 경기도 수원시 팔달구 경수대로 652 (우만동) (37.283701, 127.028943)
#   배송3: 경기도 수원시 팔달구 팔달문로139번길 7 (우만동, 센트럴하우스) (37.282850, 127.031108)
#   배송4: 경기도 수원시 팔달구 경수대로642번길 62-3 (우만동) (37.284408, 127.032396)
#   배송5: 경기도 수원시 팔달구 창룡대로 194 (우만동, 주공4단지아파트) (37.291738, 127.030353)
#   배송6: 경기도 수원시 장안구 창훈로 30 (연무동) (37.294808, 127.031350)
#   배송7: 경기도 수원시 장안구 연무로 24 (연무동) (37.294180, 127.028675)
#   배송8: 경기도 수원시 장안구 연무로42번길 14-21(연무동) (37.295341, 127.027923)
#   배송9: 경기도 수원시 장안구 창훈로39번길 36 (연무동) (37.296456, 127.028446)
#   배송10: 경기도 수원시 장안구 창훈로 74 (연무동, 서광교파크뷰) (37.298097, 127.027802)
#   배송11: 경기도 수원시 장안구 금당로39번길 34 (조원동, 주공뉴타운) (37.302535, 127.019148)
#   배송12: 경기도 수원시 장안구 조원로 107 (조원동) (37.302090, 127.014140)
#   배송13: 경기도 수원시 장안구 송원로86번길 31 (조원동, 새롬아트빌) (37.301462, 127.011618)
#   배송14: 경기도 수원시 장안구 송원로59번길 50 (송죽동, 성우빌라) (37.302050, 127.006313)
#   배송15: 경기도 수원시 장안구 경수대로995번길 11-34(송죽동) (37.304364, 127.002844)
#   배송16: 경기도 수원시 장안구 수일로118번길 5 (송죽동) (37.308481, 127.003410)
#   배송17: 경기도 수원시 장안구 파장로76번길 11 (파장동, 건우까사미2차) (37.306783, 126.992660)
#   배송18: 경기도 수원시 장안구 파장로100번길 37-9 (파장동) (37.308792, 126.990991)
#   배송19: 경기도 수원시 장안구 파장로100번길 37-9 (파장동) (37.308792, 126.990991)
#   배송20: 경기도 수원시 장안구 파장로100번길 37-9 (파장동) (37.308792, 126.990991)
#   배송21: 경기도 수원시 장안구 장안로359번길 20(이목동, 수원장안힐스테이트) (37.312043, 126.984118)
#   배송22: 경기도 수원시 장안구 정자천로188번길 64(정자동, 화서역 현대벽산) (37.293505, 126.996630)
#   배송23: 경기도 수원시 장안구 수성로261번길 81 (정자동) (37.292992, 126.998550)
#   배송24: 경기도 수원시 장안구 송정로76번길 14 (정자동, 가림아파트) (37.295222, 127.005550)
#   배송25: 경기도 수원시 장안구 영화로71번길 24 (정자동) (37.292668, 127.005264)
#   배송26: 경기도 수원시 장안구 장안로18번길 15(영화동) (37.287136, 127.007079)
#   배송27: 경기도 수원시 팔달구 장안로5번길 27-5 (화서동) (37.285281, 127.005850)
#   배송28: 경기도 수원시 팔달구 인계로 21 (인계동) (37.271616, 127.022556)
#   배송29: 경기도 수원시 팔달구 장다리로233번길 19 (인계동) (37.270744, 127.025247)
#
# [차량 5번]
# - 배송지점 수: 23개
# - 이동거리: 15.1km
# - 소요시간: 134분 (2.2시간)
# - 상세 경로:
#   출발: 수원센터 (37.263573, 127.028601)
#   배송1: 경기도 수원시 팔달구 매산로126번길 30-2 (매교동) (37.270617, 127.015151)
#   배송2: 경기도 수원시 팔달구 고화로72번길 9-13 (고등동, 예담빌) (37.276312, 127.006901)
#   배송3: 경기도 수원시 팔달구 화양로38번길 136-4(화서동, 칠성아파트) (37.281377, 127.003629)
#   배송4: 경기도 수원시 팔달구 화산로 57(화서동, 꽃뫼버들마을 진흥아파트) (37.289245, 126.983635)
#   배송5: 경기도 수원시 장안구 화산로 85 (천천동, 화서역푸르지오더에듀포레) (37.292236, 126.980555)
#   배송6: 경기도 수원시 장안구 화산로 85 (천천동, 화서역푸르지오더에듀포레) (37.292236, 126.980555)
#   배송7: 경기도 수원시 장안구 서부로 2065 (율전동, 삼성아파트) (37.292601, 126.969368)
#   배송8: 경기도 수원시 장안구 서부로 2065 (율전동, 삼성아파트) (37.292601, 126.969368)
#   배송9: 경기도 수원시 장안구 화산로187번길 19 (천천동, 천천 삼성래미안) (37.297630, 126.976302)
#   배송10: 경기도 수원시 장안구 화산로187번길 19 (천천동, 천천 삼성래미안) (37.297630, 126.976302)
#   배송11: 경기도 수원시 장안구 화산로187번길 19 (천천동, 천천 삼성래미안) (37.297630, 126.976302)
#   배송12: 경기도 수원시 장안구 화산로213번길 9-15 (율전동) (37.299142, 126.973644)
#   배송13: 경기도 수원시 장안구 덕영대로407번길 83 (율전동, 서희스타힐스3단지) (37.304655, 126.967174)
#   배송14: 경기도 수원시 장안구 상률로 32 (율전동, 밤꽃마을뜨란채) (37.305903, 126.968674)
#   배송15: 경기도 수원시 장안구 하률로11번길 26 (천천동) (37.304076, 126.974053)
#   배송16: 경기도 수원시 장안구 하률로46번길 22(천천동, 삼호진덕아파트) (37.302400, 126.977698)
#   배송17: 경기도 수원시 장안구 정자로41번길 12 (천천동, 비단마을 신명아파트) (37.301160, 126.981974)
#   배송18: 경기도 수원시 장안구 만석로20번길 28 (정자동, 청솔마을 한라 아파트) (37.294151, 126.984166)
#   배송19: 경기도 수원시 장안구 만석로20번길 25 (정자동, 청솔마을 SK한화아파트) (37.294967, 126.985663)
#   배송20: 경기도 수원시 장안구 만석로68번길 10 (정자동, 백설마을 현대.코오롱아파트) (37.296429, 126.988236)
#   배송21: 경기도 수원시 장안구 수성로245번길 40-8 (정자동, 정자연립) (37.291074, 126.998914)
#   배송22: 경기도 수원시 팔달구 인계로 20(매교동) (37.270200, 127.018209)
#   배송23: 경기도 수원시 팔달구 인계로 20(매교동) (37.270200, 127.018209)
#
# [차량 6번]
# - 배송지점 수: 29개
# - 이동거리: 18.8km
# - 소요시간: 170분 (2.8시간)
# - 상세 경로:
#   출발: 수원센터 (37.263573, 127.028601)
#   배송1: 경기도 수원시 팔달구 효원로93번길 33(매교동) (37.267986, 127.011066)
#   배송2: 경기도 수원시 팔달구 효원로93번길 33(매교동) (37.267986, 127.011066)
#   배송3: 경기도 수원시 팔달구 효원로93번길 33(매교동) (37.267986, 127.011066)
#   배송4: 경기도 수원시 팔달구 갓매산로71번길 21-6 (매산로2가) (37.268820, 127.003141)
#   배송5: 경기도 수원시 권선구 세화로168번길 15 (서둔동, 센트라우스) (37.268667, 126.995581)
#   배송6: 경기도 수원시 권선구 세화로168번길 15 (서둔동, 센트라우스) (37.268667, 126.995581)
#   배송7: 경기도 수원시 권선구 상탑로53번길 9-7 (탑동) (37.271805, 126.976470)
#   배송8: 경기도 수원시 권선구 금곡로 229 (금곡동) (37.275311, 126.955356)
#   배송9: 경기도 수원시 권선구 금곡로197번길 28(금곡동) (37.274783, 126.951976)
#   배송10: 경기도 수원시 권선구 서수원로 589 (금곡동, 삼익3차아파트) (37.277355, 126.954862)
#   배송11: 경기도 수원시 권선구 서수원로591번길 43 (금곡동, 거산아파트) (37.277879, 126.953119)
#   배송12: 경기도 수원시 권선구 당수로130번길 13 (당수동) (37.286512, 126.944317)
#   배송13: 경기도 수원시 권선구 당진로31번길 51-18 (당수동, 서수원2차쌍용스윗닷홈) (37.292763, 126.936836)
#   배송14: 경기도 수원시 권선구 당진로22번길 6 (당수동) (37.291037, 126.941007)
#   배송15: 경기도 수원시 권선구 구운로85번길 47-24 (구운동, 가림아파트) (37.279851, 126.970465)
#   배송16: 경기도 수원시 권선구 여기산로 54 (서둔동, 동남아파트) (37.282557, 126.979650)
#   배송17: 경기도 수원시 팔달구 동말로 20-1 (화서동, 뉴골든빌라) (37.277563, 126.996690)
#   배송18: 경기도 수원시 팔달구 동말로16번길 14 (화서동, 황제연립) (37.276845, 126.996351)
#   배송19: 경기도 수원시 팔달구 동말로16번길 14 (화서동, 황제연립) (37.276845, 126.996351)
#   배송20: 경기도 수원시 팔달구 동말로16번길 14 (화서동, 황제연립) (37.276845, 126.996351)
#   배송21: 경기도 수원시 팔달구 동말로16번길 14 (화서동, 황제연립) (37.276845, 126.996351)
#   배송22: 경기도 수원시 팔달구 고등로 15 (고등동, 수원역푸르지오자이) (37.275502, 126.998949)
#   배송23: 경기도 수원시 팔달구 고등로 8 (고등동, 수원고등 LH2단지) (37.272508, 126.998004)
#   배송24: 경기도 수원시 팔달구 고등로 15(고등동, 수원역푸르지오자이) (37.273357, 126.999288)
#   배송25: 경기도 수원시 팔달구 고화로 34-1 (고등동) (37.272532, 127.006838)
#   배송26: 경기도 수원시 팔달구 고화로14번길 6 (매산로3가) (37.270733, 127.008160)
#   배송27: 경기도 수원시 팔달구 효원로93번길 33 (매교동, 힐스테이트 푸르지오 수원) (37.268266, 127.012272)
#   배송28: 경기도 수원시 팔달구 효원로93번길 34 (매교동, 힐스테이트 푸르지오 수원) (37.267614, 127.014056)
#   배송29: 경기도 수원시 팔달구 경수대로421번길 14-17 (인계동) (37.264928, 127.024565)
#
# [차량 7번]
# - 배송지점 수: 17개
# - 이동거리: 16.5km
# - 소요시간: 110분 (1.8시간)
# - 상세 경로:
#   출발: 수원센터 (37.263573, 127.028601)
#   배송1: 경기도 수원시 팔달구 덕영대로 923-10 (매산로1가) (37.265945, 127.001691)
#   배송2: 경기도 수원시 권선구 서둔로200번길 18 (서둔동, 모던힐 하우스) (37.269730, 126.980589)
#   배송3: 경기도 수원시 권선구 하탑로9번길 31 (탑동) (37.269797, 126.972210)
#   배송4: 경기도 수원시 권선구 매곡로 67 (금곡동, 호반써밋 수원) (37.271851, 126.953557)
#   배송5: 경기도 수원시 권선구 매곡로 67 (금곡동, 호반써밋 수원) (37.271851, 126.953557)
#   배송6: 경기도 수원시 권선구 금곡로196번길 35 (금곡동) (37.273250, 126.953169)
#   배송7: 경기도 수원시 권선구 금곡로197번길 18-20 (금곡동) (37.274516, 126.952488)
#   배송8: 경기도 수원시 권선구 금곡로 137 (금곡동, 수원호매실휴먼시아4단지아파트) (37.275301, 126.946309)
#   배송9: 경기도 수원시 권선구 서수원로577번길 305(금곡동, 수원모아미래도센트럴타운2단지) (37.275987, 126.940431)
#   배송10: 경기도 수원시 권선구 서수원로577번길 341 (금곡동, 수원모아미래도센트럴타운1단지) (37.275903, 126.938195)
#   배송11: 경기도 수원시 권선구 금곡로 45 (금곡동, 금곡엘지아파트) (37.271342, 126.937712)
#   배송12: 경기도 수원시 권선구 금곡로102번길 126(호매실동, 수원호매실휴먼시아7단지아파트) (37.269138, 126.941932)
#   배송13: 경기도 수원시 권선구 매실로19번길 19 (호매실동, 쌍용아파트) (37.267997, 126.952680)
#   배송14: 경기도 수원시 권선구 노림로6번길 12 (호매실동, 신라궁전타운) (37.266314, 126.955146)
#   배송15: 경기도 수원시 권선구 노림로6번길 12 (호매실동, 신라궁전타운) (37.266314, 126.955146)
#   배송16: 경기도 수원시 권선구 세화로162번길 16 (서둔동) (37.266365, 126.994491)
#   배송17: 경기도 수원시 권선구 효원로 184 (권선동) (37.263954, 127.022000)
#
# 4. 시간 분포 분석
# - 최소 소요시간: 110분 (1.8시간)
# - 최대 소요시간: 237분 (4.0시간)
# - 시간 범위: 127분
# - 평균 소요시간: 180분 (3.0시간)
# - 중앙값 소요시간: 170분
#
# 5. 거리 분포 분석
# - 최소 이동거리: 14.0km
# - 최대 이동거리: 23.3km
# - 거리 범위: 9.3km
# - 평균 이동거리: 17.8km
# - 중앙값 이동거리: 16.5km
#
# 6. 배송지점 분포 분석
# - 최소 배송지점: 17개
# - 최대 배송지점: 45개
# - 배송지점 범위: 28개
# - 평균 배송지점: 31.6개
# - 중앙값 배송지점: 29개
#
# 7. 효율성 지표
# - km당 배송지점: 1.77개/km
# - 시간당 배송지점: 10.54개/시간
# - 차량당 평균 가동률: 42.8%
#
# === 지도 시각화 생성 중 ===
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a7ce3f34967f00299c178ffeac9efbc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a7ce3f34967f00299c178ffeac9efbc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5a7ce3f34967f00299c178ffeac9efbc = L.map(
#                 &quot;map_5a7ce3f34967f00299c178ffeac9efbc&quot;,
#                 {
#                     center: [37.263573, 127.028601],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_122836dc9d5df519c5a0b37181d67127 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_122836dc9d5df519c5a0b37181d67127.addTo(map_5a7ce3f34967f00299c178ffeac9efbc);
#
#
#             var marker_7b8fb8218007a68b0cf2fd6a550621b2 = L.marker(
#                 [37.263573, 127.028601],
#                 {
# }
#             ).addTo(map_5a7ce3f34967f00299c178ffeac9efbc);
#
#
#             var icon_e5cf0bd8bfa15b21989f22e4a9b820d5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c4fcdbb701847655ec4166a7b72b2da3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_314fb52e7ca93f1ce75959e46166395c = $(`&lt;div id=&quot;html_314fb52e7ca93f1ce75959e46166395c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Depot: depot_수원&lt;/div&gt;`)[0];
#                 popup_c4fcdbb701847655ec4166a7b72b2da3.setContent(html_314fb52e7ca93f1ce75959e46166395c);
#
#
#
#         marker_7b8fb8218007a68b0cf2fd6a550621b2.bindPopup(popup_c4fcdbb701847655ec4166a7b72b2da3)
#         ;
#
#
#
#
#                 marker_7b8fb8218007a68b0cf2fd6a550621b2.setIcon(icon_e5cf0bd8bfa15b21989f22e4a9b820d5);
#
#
#             var poly_line_9e35b4f333652191021b9156bcf2f61d = L.polyline(
#                 [[37.263573, 127.028601], [37.2577787, 127.0276652], [37.253907, 127.0228244], [37.2523721, 127.0184127], [37.2535136, 127.0144687], [37.2535136, 127.0144687], [37.2467096, 127.0149848], [37.2451197, 127.0294582], [37.23915987695681, 127.02566376365826], [37.2357129, 127.0273247], [37.2357129, 127.0273247], [37.2357129, 127.0273247], [37.2357129, 127.0273247], [37.2359423, 127.025672], [37.2351387, 126.9752315], [37.246201, 126.979313], [37.246201, 126.979313], [37.2482937267593, 126.977667058211], [37.2481731, 126.962796], [37.2540833, 126.9590665], [37.2599414, 126.9608585], [37.2625787, 126.9604488], [37.2566661, 126.9758435], [37.2606204, 126.9879174], [37.2617228, 126.9908402], [37.2617228, 126.9908402], [37.2620083, 126.9917404], [37.2611277, 126.992733], [37.2624112, 127.0007549], [37.2624112, 127.0007549], [37.2633295, 127.004994], [37.2611573, 127.0057183], [37.2591328, 127.0078659], [37.2601971, 127.0114119], [37.2584143, 127.0164402], [37.2581928, 127.0172718], [37.2581928, 127.0172718], [37.2581753, 127.0178289], [37.2610753, 127.023534]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_5a7ce3f34967f00299c178ffeac9efbc);
#
#
#         var popup_202b94c5a7c3440bf5e023eedb4eed9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d16c527ce4be05e163767c01ade8439c = $(`&lt;div id=&quot;html_d16c527ce4be05e163767c01ade8439c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Distance: 20.8km, Time: 217min&lt;/div&gt;`)[0];
#                 popup_202b94c5a7c3440bf5e023eedb4eed9f.setContent(html_d16c527ce4be05e163767c01ade8439c);
#
#
#
#         poly_line_9e35b4f333652191021b9156bcf2f61d.bindPopup(popup_202b94c5a7c3440bf5e023eedb4eed9f)
#         ;
#
#
#
#
#             var circle_marker_816453f6945dcecaa54a280894b5b271 = L.circleMarker(
#                 [37.2577787, 127.0276652],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;
